# %% [markdown]
# # Text to Image

# %%
pip install DiffusionPipeline
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement DiffusionPipeline (from versions: none)
# ERROR: No matching distribution found for DiffusionPipeline

# %%
# !pip install diffusers transformers accelerate safetensors --upgrade
# Out:
# Collecting diffusers
#   Downloading diffusers-0.34.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: transformers in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (4.53.2)
# Collecting accelerate
#   Downloading accelerate-1.8.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: safetensors in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (0.5.3)
# Requirement already satisfied: importlib_metadata in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from diffusers) (8.5.0)
# Requirement already satisfied: filelock in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from diffusers) (3.17.0)
# Requirement already satisfied: huggingface-hub>=0.27.0 in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from diffusers) (0.33.4)
# Requirement already satisfied: numpy in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from diffusers) (2.1.3)
# Requirement already satisfied: regex!=2019.12.17 in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from diffusers) (2024.11.6)
# Requirement already satisfied: requests in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from diffusers) (2.32.3)
# Requirement already satisfied: Pillow in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from diffusers) (11.1.0)
# Requirement already satisfied: packaging>=20.0 in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from transformers) (0.21.2)
# Requirement already satisfied: tqdm>=4.27 in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from huggingface-hub>=0.27.0->diffusers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from huggingface-hub>=0.27.0->diffusers) (4.12.2)
# Requirement already satisfied: psutil in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: torch>=2.0.0 in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from accelerate) (2.7.1)
# Requirement already satisfied: sympy>=1.13.3 in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from torch>=2.0.0->accelerate) (1.13.3)
# Requirement already satisfied: networkx in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: setuptools in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from torch>=2.0.0->accelerate) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: colorama in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: zipp>=3.20 in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from importlib_metadata->diffusers) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from requests->diffusers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from requests->diffusers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from requests->diffusers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\mohitg\appdata\local\anaconda3\lib\site-packages (from requests->diffusers) (2025.4.26)
# Downloading diffusers-0.34.0-py3-none-any.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 3.8/3.8 MB 25.0 MB/s eta 0:00:00
# Downloading accelerate-1.8.1-py3-none-any.whl (365 kB)
# Installing collected packages: diffusers, accelerate
#
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    ---------------------------------------- 0/2 [diffusers]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    ---------------------------------------- 2/2 [accelerate]
#
# Successfully installed accelerate-1.8.1 diffusers-0.34.0

# %%
from diffusers import DiffusionPipeline

pipe = DiffusionPipeline.from_pretrained("playgroundai/playground-v2.5-1024px-aesthetic")

prompt = "Astronaut in a jungle, cold color palette, muted colors, detailed, 8k"
image = pipe(prompt).images[0]
# Out:
# Fetching 18 files:   0%|          | 0/18 [00:00<?, ?it/s]
# D:\Users\mohitg\AppData\Local\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:799: UserWarning: Not enough free disk space to download the file. The expected file size is: 10270.08 MB. The target location D:\Users\mohitg\.cache\huggingface\hub\models--playgroundai--playground-v2.5-1024px-aesthetic\blobs only has 5.07 MB free disk space.
#   warnings.warn(
# diffusion_pytorch_model.safetensors:  47%|####7     | 9.26G/19.5G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 3
#       1 from diffusers import DiffusionPipeline
# ----> 3 pipe = DiffusionPipeline.from_pretrained("playgroundai/playground-v2.5-1024px-aesthetic")
#       5 prompt = "Astronaut in a jungle, cold color palette, muted colors, detailed, 8k"
#       6 image = pipe(prompt).images[0]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\diffusers\pipelines\pipeline_utils.py:833, in DiffusionPipeline.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     828     if pretrained_model_name_or_path.count("/") > 1:
#     829         raise ValueError(
#     830             f'The provided pretrained_model_name_or_path "{pretrained_model_name_or_path}"'
#     831             " is neither a valid local path nor a valid repo id. Please check the parameter."
#     832         )
# --> 833     cached_folder = cls.download(
#     834         pretrained_model_name_or_path,
#     835         cache_dir=cache_dir,
#     836         force_download=force_download,
#     837         proxies=proxies,
#     838         local_files_only=local_files_only,
#     839         token=token,
#     840         revision=revision,
#     841         from_flax=from_flax,
#     842         use_safetensors=use_safetensors,
#     843         use_onnx=use_onnx,
#     844         custom_pipeline=custom_pipeline,
#     845         custom_revision=custom_revision,
#     846         variant=variant,
#     847         dduf_file=dduf_file,
#     848         load_connected_pipeline=load_connected_pipeline,
#     849         **kwargs,
#     850     )
#     851 else:
#     852     cached_folder = pretrained_model_name_or_path
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\diffusers\pipelines\pipeline_utils.py:1627, in DiffusionPipeline.download(cls, pretrained_model_name, **kwargs)
#    1625 # download all allow_patterns - ignore_patterns
#    1626 try:
# -> 1627     cached_folder = snapshot_download(
#    1628         pretrained_model_name,
#    1629         cache_dir=cache_dir,
#    1630         proxies=proxies,
#    1631         local_files_only=local_files_only,
#    1632         token=token,
#    1633         revision=revision,
#    1634         allow_patterns=allow_patterns,
#    1635         ignore_patterns=ignore_patterns,
#    1636         user_agent=user_agent,
#    1637     )
#    1639     cls_name = cls.load_config(os.path.join(cached_folder, "model_index.json")).get("_class_name", None)
#    1640     cls_name = cls_name[4:] if isinstance(cls_name, str) and cls_name.startswith("Flax") else cls_name
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\huggingface_hub\_snapshot_download.py:327, in snapshot_download(repo_id, repo_type, revision, cache_dir, local_dir, library_name, library_version, user_agent, proxies, etag_timeout, force_download, token, local_files_only, allow_patterns, ignore_patterns, max_workers, tqdm_class, headers, endpoint, local_dir_use_symlinks, resume_download)
#     325         _inner_hf_hub_download(file)
#     326 else:
# --> 327     thread_map(
#     328         _inner_hf_hub_download,
#     329         filtered_repo_files,
#     330         desc=tqdm_desc,
#     331         max_workers=max_workers,
#     332         # User can use its own tqdm class or the default one from `huggingface_hub.utils`
#     333         tqdm_class=tqdm_class or hf_tqdm,
#     334     )
#     336 if local_dir is not None:
#     337     return str(os.path.realpath(local_dir))
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tqdm\contrib\concurrent.py:69, in thread_map(fn, *iterables, **tqdm_kwargs)
#      55 """
#      56 Equivalent of `list(map(fn, *iterables))`
#      57 driven by `concurrent.futures.ThreadPoolExecutor`.
#    (...)
#      66     [default: max(32, cpu_count() + 4)].
#      67 """
#      68 from concurrent.futures import ThreadPoolExecutor
# ---> 69 return _executor_map(ThreadPoolExecutor, fn, *iterables, **tqdm_kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tqdm\contrib\concurrent.py:51, in _executor_map(PoolExecutor, fn, *iterables, **tqdm_kwargs)
#      47 with ensure_lock(tqdm_class, lock_name=lock_name) as lk:
#      48     # share lock in case workers are already using `tqdm`
#      49     with PoolExecutor(max_workers=max_workers, initializer=tqdm_class.set_lock,
#      50                       initargs=(lk,)) as ex:
# ---> 51         return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs))
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tqdm\notebook.py:250, in tqdm_notebook.__iter__(self)
#     248 try:
#     249     it = super().__iter__()
# --> 250     for obj in it:
#     251         # return super(tqdm...) will not catch exception
#     252         yield obj
#     253 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tqdm\std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~\AppData\Local\anaconda3\Lib\concurrent\futures\_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~\AppData\Local\anaconda3\Lib\concurrent\futures\_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~\AppData\Local\anaconda3\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~\AppData\Local\anaconda3\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Local\anaconda3\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\huggingface_hub\_snapshot_download.py:301, in snapshot_download.<locals>._inner_hf_hub_download(repo_file)
#     300 def _inner_hf_hub_download(repo_file: str):
# --> 301     return hf_hub_download(
#     302         repo_id,
#     303         filename=repo_file,
#     304         repo_type=repo_type,
#     305         revision=commit_hash,
#     306         endpoint=endpoint,
#     307         cache_dir=cache_dir,
#     308         local_dir=local_dir,
#     309         local_dir_use_symlinks=local_dir_use_symlinks,
#     310         library_name=library_name,
#     311         library_version=library_version,
#     312         user_agent=user_agent,
#     313         proxies=proxies,
#     314         etag_timeout=etag_timeout,
#     315         resume_download=resume_download,
#     316         force_download=force_download,
#     317         token=token,
#     318         headers=headers,
#     319     )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1008, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     988     return _hf_hub_download_to_local_dir(
#     989         # Destination
#     990         local_dir=local_dir,
#    (...)
#    1005         local_files_only=local_files_only,
#    1006     )
#    1007 else:
# -> 1008     return _hf_hub_download_to_cache_dir(
#    1009         # Destination
#    1010         cache_dir=cache_dir,
#    1011         # File info
#    1012         repo_id=repo_id,
#    1013         filename=filename,
#    1014         repo_type=repo_type,
#    1015         revision=revision,
#    1016         # HTTP info
#    1017         endpoint=endpoint,
#    1018         etag_timeout=etag_timeout,
#    1019         headers=hf_headers,
#    1020         proxies=proxies,
#    1021         token=token,
#    1022         # Additional options
#    1023         local_files_only=local_files_only,
#    1024         force_download=force_download,
#    1025     )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1161, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1158 # Local file doesn't exist or etag isn't a match => retrieve file from remote (or cache)
#    1160 with WeakFileLock(lock_path):
# -> 1161     _download_to_tmp_and_move(
#    1162         incomplete_path=Path(blob_path + ".incomplete"),
#    1163         destination_path=Path(blob_path),
#    1164         url_to_download=url_to_download,
#    1165         proxies=proxies,
#    1166         headers=headers,
#    1167         expected_size=expected_size,
#    1168         filename=filename,
#    1169         force_download=force_download,
#    1170         etag=etag,
#    1171         xet_file_data=xet_file_data,
#    1172     )
#    1173     if not os.path.exists(pointer_path):
#    1174         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1725, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download, etag, xet_file_data)
#    1718         if xet_file_data is not None:
#    1719             logger.warning(
#    1720                 "Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. "
#    1721                 "Falling back to regular HTTP download. "
#    1722                 "For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`"
#    1723             )
# -> 1725         http_get(
#    1726             url_to_download,
#    1727             f,
#    1728             proxies=proxies,
#    1729             resume_size=resume_size,
#    1730             headers=headers,
#    1731             expected_size=expected_size,
#    1732         )
#    1734 logger.info(f"Download complete. Moving file to {destination_path}")
#    1735 _chmod_and_move(incomplete_path, destination_path)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:497, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     495 if chunk:  # filter out keep-alive new chunks
#     496     progress.update(len(chunk))
# --> 497     temp_file.write(chunk)
#     498     new_resume_size += len(chunk)
#     499     # Some data has been downloaded from the server so we reset the number of retries.
#
# OSError: [Errno 28] No space left on device

# %%
from PIL import Image

img = Image.fromarray(image)
img.save("output1.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 from PIL import Image
# ----> 3 img = Image.fromarray(image)
#       4 img.save("output1.png")
#
# NameError: name 'image' is not defined
